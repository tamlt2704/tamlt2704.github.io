# %%
#!pip install --upgrade Pillow
from PIL import Image, ImageDraw
from itertools import product 
import os
img = Image.open('./public/fruitspritesheet.png')
# print(im.format, im.size, im.mode)

# name, ext = os.path.splitext(filename)
# img = Image.open(os.path.join(dir_in, filename))
w, h = img.size

# d= 150
# grid = product(range(0, h-h%d, d), range(0, w-w%d, d))
# for i, j in grid:
#     box = (j, i, j+d, i+d)
#     out = os.path.join('tmp', f'{i}_{j}.png')
#     img.crop(box).save(out)

draw = ImageDraw.Draw(img)
# draw.line((,200, 150,300), fill=128)
y = list(range(0, h, 160))
yx = [20, 180, 340, 510, 680, 840, 1015]
xx = [0, 145, 290, 425, 565, 720, 855]
for i in yx:
    draw.line((0,i, w, i), fill=128)
for i in xx:    
    draw.line((i,0, i, h), fill=128)
print(y)
display(img)
# Out:
# [0, 160, 320, 480, 640, 800, 960]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
# display(im)
